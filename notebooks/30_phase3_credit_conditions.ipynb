# %% [markdown]
# <a href="https://colab.research.google.com/github/sl007ha/qqq-risk-monitor/blob/phase2-v32-clean/notebooks/30_phase3_credit_conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
